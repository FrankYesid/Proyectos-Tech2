# %% [markdown]
# # MODELO PARA RECOMENDACIÓN DE LIBROS PERSONALIZADA BASADO EN INTELIGENCIA ARTIFICIAL
#
# ![](https://img.freepik.com/foto-gratis/dia-internacional-educacion-estilo-futurista-robot-estudiante_23-2150998732.jpg?t=st=1742004884~exp=1742008484~hmac=231fadcf45b36dde74d1af2c58db44e62a9c9b36f7ecdd49d3f28a3dd46994ef&w=900)
#
# Con el objetivo de crear un programa para fomentar la lectura en personas de 18 años en adelante, se elige un conjunto de datos del país de México que recopila estudios de encuestas desde el año 2019 hasta el año 2024.
#
# Este conjunto contiene características como clasificación de vivienda, tipo de texto que suele consumir el lector, motivo por el cual lee, edad, escolaridad, actividad qué desempeña, frecuencia de lectura, entre otros.
#
#
# ## Características del Conjunto de Datos
#
# ### Información Básica de las Variables:
#
# A continuación, se presenta la información de las variables más significativas de este proyecto.
#
# - entidad: Departamentos.
# - num_hog: Vivienda.
# - n_ren_ele: Renglón del integrante del hogar.
# - p12_9:¿La(s) revista(s) que leyó fue(ron) otro?
# - perslecl:Estatus de las personas en condición de lectura de materiales considerados por MOLEC
# - p12_5:¿La(s) revista(s) que leyó fue(ron) religiosas (Atalaya, Vida nueva, Despertares, etcétera)?
# - p12_1:¿La(s) revista(s) que leyó fue(ron) de deportes o automovilismo (Sports Illustrated, Automóvil panamericano, Motociclismo, etcétera)?
# - p12_3:¿La(s) revista(s) que leyó fue(ron) didáctica(s), sobre manualidades, cocina o decoración (Carpintería, Dos agujas, Cocina Fácil, etcétera)?
# - p12_8:¿La(s) revista(s) que leyó fue(ron) otro?
# - r_format:Formato de revistas
# - p14_1:¿La(s) revista(s) que leyó se encontraba(n) en formato digital?
# - p12_4:¿La(s) revista(s) que leyó fue(ron) de bienestar o salud (Men’s  health, Women’s health, Cuerpo mente, Salud vital, etcétera)?
# - p12_7:¿La(s) revista(s) que leyó fue(ron) de cultura general o temas de interés (Selecciones, Contenido, Algarabía, etcétera)?
#
#
# ### Fuente
# Módulo sobre Lectura (MOLEC)
#
# Información Demográfica y Social
# https://www.inegi.org.mx/programas/molec/#datos_abiertos

# %% [markdown]
# ## ✨ Autores
# 👨‍💻 Angélica María Arboleda Salazar
#
# 👨‍💻 María Paz Estrada Granada
#
# 👨‍💻 Luis Alberto Ramírez Ospina
#
# 📌 *Creadores de este cuaderno*
#
# 📧 Contactos:
#
# [angelica.2051714552@ucaldas.edu.co](mailto:angelica.2051714552@ucaldas.edu.co)
#
# [mariapazestradagranada@gmail.com](mailto:mariapazestradagranada@gmail.com)
#
# [beto.laro51@gmail.com](mailto:beto.laro51@gmail.com)

# %% [markdown]
# CARGAR DESDE DRIVE

# %%
# @title Conexión con la base de datos desde una URL

#@markdown - Forma 1 de descarga de archivos desde Google Drive con wget
# Forma de descarga de archivos desde Google Drive con wget
# Se requiere el uso de cookies para la autenticación
# Se debe obtener el ID del archivo de Google Drive para poder descargarlo
# Se usa el comando wget para descargar el archivo, gestionando las cookies
# param url: URL de la base de datos
# param nombre_archivo: Nombre del archivo a guardar



# Descargar el archivo usando wget, gestionando las cookies
# Se usa --load-cookies para cargar las cookies guardadas temporalmente en /tmp/cookies.txt
# Se hace una primera solicitud con wget para obtener el token de confirmación que Google Drive envía cuando el archivo es grande o muy accedido
# El token se extrae usando sed (una utilidad para filtrar y procesar texto), que busca el patrón "confirm=" y captura el valor del token
# Una vez obtenido el token de confirmación, se realiza la descarga completa del archivo
# --no-check-certificate es usado para evitar errores de SSL (certificados) en entornos no seguros
# El archivo se guarda como "Spotify_Most_Streamed_Songs.csv" . indicado con el nombre del archivo en la variable "nombre_archivo"
# Finalmente, se eliminan las cookies temporales almacenadas en /tmp/cookies.txt

#ARCHIVO 1 AÑO 2019

# URL = 'https://drive.google.com/file/d/1xysYAudwRoxZxXff-W7XGWOefxpInSEF/view?usp=sharing'
# Definir el ID del archivo de Google Drive
FILEID = '1xysYAudwRoxZxXff-W7XGWOefxpInSEF'
nombre_archivo2019 = 'conjunto_de_datos_molec_2019_02.csv'

# con esta instrucción se descarga el archivo desde Google Drive
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O $nombre_archivo2019 && rm -rf /tmp/cookies.txt

#ARCHIVO 2 AÑO 2020

# URL = 'https://drive.google.com/file/d/1ZYOpYCwFYJnnk6bd6yaY8TkCoc9HKGo4/view?usp=sharing'
# Definir el ID del archivo de Google Drive
FILEID = '1ZYOpYCwFYJnnk6bd6yaY8TkCoc9HKGo4'
nombre_archivo2020 = 'conjunto_de_datos_molec_2020_02.csv'

# con esta instrucción se descarga el archivo desde Google Drive
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O $nombre_archivo2020 && rm -rf /tmp/cookies.txt


#ARCHIVO 3 AÑO 2021

# URL = 'https://drive.google.com/file/d/1R7wadBazm31hH3fMT5IAiCBywOW_TyTw/view?usp=sharing'
# Definir el ID del archivo de Google Drive
FILEID = '1R7wadBazm31hH3fMT5IAiCBywOW_TyTw'
nombre_archivo2021 = 'conjunto_de_datos_molec_2021_02.csv'

# con esta instrucción se descarga el archivo desde Google Drive
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O $nombre_archivo2021 && rm -rf /tmp/cookies.txt

#ARCHIVO 4 AÑO 2022

# URL = 'https://drive.google.com/file/d/1_9tkZC7rc79VMGf60lTLNNAstu6q2-I5/view?usp=sharing'
# Definir el ID del archivo de Google Drive
FILEID = '1_9tkZC7rc79VMGf60lTLNNAstu6q2-I5'
nombre_archivo2022 = 'conjunto_de_datos_molec_2022_02.csv'

# con esta instrucción se descarga el archivo desde Google Drive
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O $nombre_archivo2022 && rm -rf /tmp/cookies.txt


#ARCHIVO 5 AÑO 2023

# URL = 'https://drive.google.com/file/d/13Pa45oOxYwLOwJZjlTw-7YND7cvZc4aD/view?usp=sharing'
# Definir el ID del archivo de Google Drive
FILEID = '13Pa45oOxYwLOwJZjlTw-7YND7cvZc4aD'
nombre_archivo2023 = 'conjunto_de_datos_molec_2023_02.csv'

# con esta instrucción se descarga el archivo desde Google Drive
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O $nombre_archivo2023 && rm -rf /tmp/cookies.txt

#ARCHIVO 6 AÑO 2024

# URL = 'https://drive.google.com/file/d/1OhDCJG-XMFT4_CvLXr-n0QPgsfsmTfnW/view?usp=sharing'
# Definir el ID del archivo de Google Drive
FILEID = '1OhDCJG-XMFT4_CvLXr-n0QPgsfsmTfnW'
nombre_archivo2024 = 'conjunto_de_datos_molec_2024_02.csv'

# con esta instrucción se descarga el archivo desde Google Drive
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O $nombre_archivo2024 && rm -rf /tmp/cookies.txt
# Out:
# --2025-03-15 13:08:24--  https://docs.google.com/uc?export=download&confirm=&id=1xysYAudwRoxZxXff-W7XGWOefxpInSEF
# Resolving docs.google.com (docs.google.com)... 172.217.0.78, 2607:f8b0:4025:810::200e
# Connecting to docs.google.com (docs.google.com)|172.217.0.78|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1xysYAudwRoxZxXff-W7XGWOefxpInSEF&export=download [following]
# --2025-03-15 13:08:24--  https://drive.usercontent.google.com/download?id=1xysYAudwRoxZxXff-W7XGWOefxpInSEF&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.65.97, 2607:f8b0:4025:804::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.65.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 476248 (465K) [application/octet-stream]
# Saving to: ‘conjunto_de_datos_molec_2019_02.csv’
#
# ...

# %% [markdown]
# # Desglose:
#
# - FILEID = '1M8fB-SdAEZZ98_jEaM5ifyhlh9np3D99': El ID del archivo de Google Drive que se desea descargar.
# - Primera llamada wget:
# Obtiene un token de confirmación cuando Google Drive requiere verificación extra para archivos grandes o descargados muchas veces.\
# Usa sed para buscar y extraer el token de la respuesta de Google Drive.
# - Segunda llamada wget:
# Con el token, se realiza la descarga final del archivo.\
# rm -rf /tmp/cookies.txt: Limpia las cookies temporales después de completar la descarga.

# %%
# @title Instalar librerías a usar
# %pip install sweetviz
# %pip install missingno
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 40.5 MB/s eta 0:00:00
# ...

# %%
# @title Carga de librerías
# Bibliotecas utilizadas
# ----------------------------------------------------------------------------
# pandas (pd): librería para el análisis de datos
# matplotlib (plt): librería para crear gráficos
# seaborn (sns): librería para visualizar datos de manera estética
# Sweetviz (sw): Una biblioteca de análisis y visualización de datos en Python.AHORRA MUCHO TRABAJO
# files : Importa la función para subir y descargar archivos en Google Colab.
import os
import pandas as pd
import matplotlib.pyplot as plt #relaciona una hoja del libro
import seaborn as sns #se puede usar otro nombre
import sweetviz as sw
from google.colab import files #desde google, la función de colab importe file
import numpy as np
import missingno as msno #ayuda a comprender cómo está compuesta la base de datos

# %%
# @title Carga de las funciones relacionadas
def analizar_columnas(df):
  """ comillas para comentar, buena práctica para comentar funciones en programación
  DOCUMENTACIÓN FUNCIÓN
  Analiza las columnas de un DataFrame y devuelve información estadística.

  Parámetros:
  df (DataFrame): El DataFrame a analizar. -empieza por df = función -pandas siempre relacionado con df

  Retorno:
  Un DataFrame con la información estadística de cada columna.

  Ejemplo:
  df_analizado = analizar_columnas(df)
  print(df_analizado)
  """
  info = []
  for columna in df.columns:
    unicos = df[columna].nunique()
    nulos = df[columna].isnull().sum() #llamo la clave en su variable como en los diccionarios
    total = len(df) #cuántos registros hay
    porcentaje_nulos = (nulos / total) * 100 #cuántos nulos vs el total (representación de los datos vacíos)
    info.append({ #vector, lista vacía, le agregamos en su primer elemento un diccionario ---> revisar vector info encima
      'Columna': columna,
      'Cantidad de registros': total,
      'Únicos': unicos,
      'Cantidad de nulos': nulos,
      'Porcentaje de nulos': porcentaje_nulos,
      'Registros relacionados con nulos': total - nulos
    })
  return pd.DataFrame(info) #pandas con función tabla para ingresar el nuevo diccionario y automáticamente toma los datos organizados para plasmarlos: mejor visualización. CÓMO SE COMPONE LA BASE DE DATOS, QUÉ TAN COMPLETA ESTÁ.

# %% [markdown]
# # Sección 1

# %% [markdown]
# ### Paso 1: Cargar el archivo CSV

# %%
# @title Cargar el archivo CSV de la base de datos
# Ubicación en donde se almacena en drive
df_datos_2019 = pd.read_csv(nombre_archivo2019, delimiter=',', encoding='latin1', on_bad_lines='skip')

df_datos_2020 = pd.read_csv(nombre_archivo2020, delimiter=',', encoding='latin1', on_bad_lines='skip')

df_datos_2021 = pd.read_csv(nombre_archivo2021, delimiter=',', encoding='latin1', on_bad_lines='skip')

df_datos_2022 = pd.read_csv(nombre_archivo2022, delimiter=',', encoding='latin1', on_bad_lines='skip')

df_datos_2023 = pd.read_csv(nombre_archivo2023, delimiter=',', encoding='latin1', on_bad_lines='skip')

df_datos_2024 = pd.read_csv(nombre_archivo2024, delimiter=',', encoding='latin1', on_bad_lines='skip')

# Mostrar las primeras filas del archivo para ver cómo están organizados los datos
print("Primeras 5 filas de los datos 2019:")
df_datos_2019.head() #visualizar tipo excel

print("Primeras 5 filas de los datos 2020:")
df_datos_2020.head() #visualizar tipo excel

print("Primeras 5 filas de los datos 2021:")
df_datos_2021.head() #visualizar tipo excel

print("Primeras 5 filas de los datos 2022:")
df_datos_2022.head() #visualizar tipo excel

print("Primeras 5 filas de los datos 2023:")
df_datos_2023.head() #visualizar tipo excel

print("Primeras 5 filas de los datos 2024:")
df_datos_2024.head() #visualizar tipo excel
# Out:
# Primeras 5 filas de los datos 2019:
# Primeras 5 filas de los datos 2020:
# Primeras 5 filas de los datos 2021:
# Primeras 5 filas de los datos 2022:
# Primeras 5 filas de los datos 2023:
# Primeras 5 filas de los datos 2024:
#     folio  entidad  control  viv_sel  num_hog  hog_mud  n_ren_el  cd  periodo  \
# 0  12B221        1    40002        2        1        0         1  14      224
# 1  12B221        1    40002        1        1        0         1  14      224
# 2  12B221        1    40002        3        1        0         1  14      224
# 3  12B221        1    40002        4        1        0         2  14      224
# 4  11B213        1    40003        1        1        0         1  14      224
#
#    sexo  ...  p36_3  p36_4 factor  h_lec  mat_lec  perslec  l_format  \
# 0     1  ...      1      2  36731      4        4        2         0
# 1     1  ...      1      2   9183      4        4        2         0
# 2     1  ...      1      2  36731      4        4        2         0
# ...

# %%
# prompt: necesito concatenar las bases de datso de df_datos_2019,df_datos_2020, df_datos_2021, df_datos_2022, df_datos_2023, df_datos_2024, que este en un solo dataframe

# Concatenate the dataframes
df_concatenado = pd.concat([df_datos_2019, df_datos_2020, df_datos_2021,
                            df_datos_2022, df_datos_2023, df_datos_2024], ignore_index=True)

# Display the first few rows of the concatenated dataframe
df_concatenado.head()
# Out:
#    ï»¿cd  periodo   folio  entidad  control  viv_sel  num_hog  hog_mud  \
# 0   14.0      219  11B167        1    40006        3        1        0
# 1   14.0      219  11B167        1    40006        2        1        0
# 2   14.0      219  11B167        1    40006        1        1        0
# 3   14.0      219  11B167        1    40006        4        1        0
# 4   14.0      219  11B176        1    40131        3        1        0
#
#    n_ren_ele  p1  ...  anio  nivel  cond_activ  n_ren_el  cd  cond_act  \
# 0        2.0   1  ...     3      3         1.0       NaN NaN       NaN
# 1        1.0   1  ...     3      3         8.0       NaN NaN       NaN
# 2        1.0   1  ...     6      2         1.0       NaN NaN       NaN
# 3        2.0   1  ...     5      2         7.0       NaN NaN       NaN
# 4        1.0   1  ...     3      6         8.0       NaN NaN       NaN
#
#    l_format  r_format p_format  perslecl
# 0       NaN       NaN      NaN       NaN
# ...

# %%
# @title Visualización de composición de la base de datos
# Muestra la base de datos no nulos
df_concatenado.info() #object = cadena de caracteres = string = texto
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11966 entries, 0 to 11965
# Columns: 115 entries, ï»¿cd to perslecl
# dtypes: float64(10), int64(85), object(20)
# memory usage: 10.5+ MB

# %% [markdown]
# ### Paso 2: Explorar los datos
#
# > Añadir blockquote
#
# > Añadir blockquote
#
# > Añadir blockquote
#
#
#
#
#
#
#
# Vamos a verificar la estructura de los datos, la cantidad de filas y columnas, así como cualquier dato vacío.

# %%
# @title Verificar la forma de los datos
print(f"Forma de los datos (filas, columnas): {df_concatenado.shape}")
# Out:
# Forma de los datos (filas, columnas): (11966, 115)

# %%
# @title Verificar los tipos de datos de cada columna
print("\nTipos de datos por columna:")
print(df_concatenado.dtypes)
# Out:
# Tipos de datos por columna:
# ï»¿cd       float64
# periodo       int64
# folio        object
# entidad       int64
# control       int64
#              ...
# cond_act    float64
# l_format    float64
# r_format    float64
# p_format    float64
# perslecl    float64
# Length: 115, dtype: object

# %%
#@title Contar los valores únicos por columna
print("\nValores únicos por columna:")
print(df_concatenado.nunique())
# Out:
# Valores únicos por columna:
# ï»¿cd        32
# periodo       6
# folio        84
# entidad      32
# control     624
#            ...
# cond_act     11
# l_format      4
# r_format      4
# p_format      4
# perslecl      3
# Length: 115, dtype: int64

# %%
#@title Verificar si hay datos faltantes
print("\nDatos faltantes por columna:")
print(df_concatenado.isnull().sum()) #buscar datos nulos en base de datos y revisa cuántos están incompletos
# Out:
# Datos faltantes por columna:
# ï»¿cd       9986
# periodo        0
# folio          0
# entidad        0
# control        0
#             ...
# cond_act    1980
# l_format    1980
# r_format    1980
# p_format    1980
# perslecl    1980
# Length: 115, dtype: int64

# %%
# @title Verificación de los campos con relación a la composición de la base de dato almacenada en formato CSV
df_analizado = analizar_columnas(df_concatenado)
df_analizado
# Out:
#       Columna  Cantidad de registros  Únicos  Cantidad de nulos  \
# 0       ï»¿cd                  11966      32               9986
# 1     periodo                  11966       6                  0
# 2       folio                  11966      84                  0
# 3     entidad                  11966      32                  0
# 4     control                  11966     624                  0
# ..        ...                    ...     ...                ...
# 110  cond_act                  11966      11               1980
# 111  l_format                  11966       4               1980
# 112  r_format                  11966       4               1980
# 113  p_format                  11966       4               1980
# 114  perslecl                  11966       3               1980
#
#      Porcentaje de nulos  Registros relacionados con nulos
# 0              83.453117                              1980
# 1               0.000000                             11966
# ...

# %%
# Visualizar valores nulos con un gráfico de barras
msno.bar(df_concatenado)
# Out:
# <Axes: >

# %%
# Visualizar matriz de valores faltantes
msno.matrix(df_concatenado)
# Out:
# <Axes: >

# %% [markdown]
# # Sección 2

# %% [markdown]
# ### Paso 3: Generar un informe que permite identificar qué contienen los datos

# %%
# prompt: necesito quitar las columnas donde el porcentaje de vacios este mayor a 20%

# Calculate the percentage of missing values for each column
missing_percentage = df_concatenado.isnull().sum() / len(df_concatenado) * 100

# Identify columns with more than 20% missing values
columns_to_drop = missing_percentage[missing_percentage > 20].index

# Drop the identified columns from the DataFrame
df_concatenado_ = df_concatenado.drop(columns=columns_to_drop)

# Now df_concatenado contains only the columns where the percentage of missing values is less than or equal to 20%

# %%
missing_percentage.plot(kind='bar', figsize=(10, 6))
plt.title('Porcentaje de Valores Faltantes por Columna')
plt.xlabel('Nombre Variables Columnas')
plt.ylabel('Porcentaje de Valores Faltantes')
plt.show()

# %%
# @title Análisis exploratorio de datos (EDA)
#Configurar las opciones de visualizacion Sweetviz
#Varias funciones en cascada
sw.config_parser.read_string("""
                              [Output_Defaults]
                              html_layout = widescreen
                              html_scale = 1.0
                              notebook_layout = widescreen
                              notebook_scale = 0.9
                              notebook_width = 100%
                              notebook_height = 700
                              [Layout]
                              show_logo = 0
                              """)
nombre = 'conjunto de datos'
df_concatenado_['mat_lec'] = df_concatenado_['mat_lec'].astype(str)
df_concatenado_['h_lec'] = df_concatenado_['h_lec'].astype(str)
df_concatenado_['perslec'] = df_concatenado_['perslec'].astype(str)
advert_report = sw.analyze([df_concatenado_, nombre]) # Realizamos el análisis de la base de datos inicial

#@markdown Guardar y mostrar reporte formato HTML
advert_report.show_html('EDA_conjunto_datos.html')

#@markdown Descargar y abrir el reporte en una nueva pestaña del navegador
almacenar_archivo = input('Alamcenar archivo Si o No: ').title()
if almacenar_archivo == 'Si':
  files.download('/content/EDA_conjunto_datos.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report EDA_conjunto_datos.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Alamcenar archivo Si o No: No

# %%
#@title La función advert_report.show_notebook en Sweetviz muestra el reporte de análisis exploratorio de datos (EDA) en un notebook Jupyter.

# Parámetros:

# layout: ajusta el diseño ( 'widescreen' o 'full screen' )
# w y h: ajusta el ancho y alto en píxeles
# scale: ajusta el tamaño (0.9 = 90% de la resolución original)
advert_report.show_notebook(layout='widescreen', w=1500, h=500, scale=0.9)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#@title La función advert_report.show_notebook muestra el reporte de análisis exploratorio de datos (EDA) en un notebook Jupyter, con el siguiente formato:

# layout='vertical': muestra los datos en una columna vertical
# w=1400 y h=500: ajusta el ancho y alto del reporte a 1400x500 píxeles
# scale=0.9: muestra el reporte a un 90% de su tamaño original
advert_report.show_notebook(layout='vertical', w=1400, h=500, scale=0.9)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 3 sección

# %% [markdown]
# ## Paso 4: Generación de EDA

# %%
df_concatenado_.shape
# Out:
# (11966, 97)

# %%
# con la base seleccionada
df_concatenado_.isna().sum().plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: >

# %%
# prompt: necesito que me seleccione las columnas que tienen presencia de vacíos en df_concatenado_

# Identify columns with missing values
columns_with_missing_values = df_concatenado_.columns[df_concatenado_.isnull().any()].tolist()

columns_with_missing_values
# Out:
# ['n_ren_el', 'cd', 'cond_act', 'l_format', 'r_format', 'p_format', 'perslecl']

# %%
# prompt: necesito saber cuántos registros tienen datos nulos en df_concatenado_

# Count the number of rows with any null values in df_concatenado_
null_rows = df_concatenado_.isnull().any(axis=1).sum()
print(f"Number of rows with null values: {null_rows}")
# Out:
# Number of rows with null values: 1980

# %%
df_concatenado_[['n_ren_el', 'cd', 'cond_act', 'l_format', 'r_format', 'p_format', 'perslecl']]
# Out:
#        n_ren_el    cd  cond_act  l_format  r_format  p_format  perslecl
# 0           NaN   NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN   NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN   NaN       NaN       NaN       NaN       NaN       NaN
# 3           NaN   NaN       NaN       NaN       NaN       NaN       NaN
# 4           NaN   NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...   ...       ...       ...       ...       ...       ...
# 11961       1.0  32.0       8.0       2.0       0.0       0.0       1.0
# 11962       2.0  32.0       7.0       2.0       0.0       0.0       1.0
# 11963       2.0  32.0       1.0       3.0       0.0       0.0       1.0
# 11964       5.0  32.0       6.0       1.0       0.0       0.0       1.0
# 11965       2.0  32.0       3.0       0.0       0.0       0.0       2.0
#
# [11966 rows x 7 columns]

# %%
11966 -1980
# Out:
# 9986

# %%
df_concatenado_final = df_concatenado_.dropna()

# %%
df_concatenado_final.shape
# Out:
# (9986, 97)

# %%
df_concatenado_final.isna().sum().sum()
# Out:
# 0

# %%
# %pip install h2o
# %pip install rdt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.8/265.8 MB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for h2o: filename=h2o-3.46.0.6-py2.py3-none-any.whl size=265859786 sha256=8695e49a6a04dbc3d2c2630dd5f06b93f5b837a827741cd01cb6253dcddc091d
#   Stored in directory: /root/.cache/pip/wheels/62/f9/aa/687bd54342d2981bc78e22ee9b9bc39f92006e344e7aa1e0ac
# Successfully built h2o
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.6 MB/s eta 0:00:00
# ...

# %%
# Importar librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import h2o
from h2o.estimators.kmeans import H2OKMeansEstimator
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from rdt import HyperTransformer

# %%
# 🔹 Inicializar H2O
h2o.init()

# 1️⃣ Cargar el dataset
# df = df_concatenado_final[['p12_9', 'perslecl', 'p12_5', 'p12_1', 'p12_3', 'p12_8', 'r_format', 'p14_1', 'p12_4', 'p12_7']].copy()
# df = df_concatenado_final[['p12_9', 'perslecl', 'p12_5', 'p12_1', 'p12_3']].copy()
df = df_concatenado_final[['p12_9', 'perslecl', 'p12_5']].copy()

# 3️⃣ Aplicar transformación con RDT 🚀
ht = HyperTransformer()
ht.detect_initial_config(df)
ht.fit(df)
df_transformed = ht.transform(df)
df_transformed = pd.DataFrame(df_transformed, columns=df.columns)

# 4️⃣ Convertir a H2OFrame 📄
df_h2o = h2o.H2OFrame(df_transformed)

# 5️⃣ Aplicar PCA y reducir a 2 dimensiones
pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_transformed)

# 6️⃣ Definir valores de K a probar
k_values = range(2, 10)
sse_values = []
silhouette_values = []
cluster_results = {}

for k in k_values:
    # 🔹 Definir y entrenar K-Means en H2O
    kmeans = H2OKMeansEstimator(k=k)
    kmeans.train(x=df_h2o.columns, training_frame=df_h2o)

    # 🔹 Obtener SSE
    sse_values.append(kmeans.tot_withinss())

    # 🔹 Obtener etiquetas de clusters y calcular la silueta
    cluster_assignments = kmeans.predict(df_h2o)
    labels = h2o.as_list(cluster_assignments).values.flatten()
    # silhouette
    silhouette_avg = silhouette_score(df_pca, labels)  # Calcular silhouette
    silhouette_values.append(silhouette_avg)

    # Guardar resultados para visualización
    cluster_results[k] = labels

# 🔹 Graficar Método del Codo y Silhouette Score
fig, ax1 = plt.subplots(figsize=(8, 5))

ax1.plot(k_values, sse_values, marker='o', linestyle='--', color='b', label='SSE')
ax1.set_xlabel('Número de Clusters (k)')
ax1.set_ylabel('Suma de Errores Cuadráticos (SSE)', color='b')
ax1.tick_params(axis='y', labelcolor='b')

ax2 = ax1.twinx()
ax2.plot(k_values, silhouette_values, marker='s', linestyle='--', color='r', label='Silhouette Score')
ax2.set_ylabel('Puntuación de Silueta', color='r')
ax2.tick_params(axis='y', labelcolor='r')

plt.title('Método del Codo y Silhouette Score para K-Means')
plt.show()

# 🔹 Visualización de los Clusters en 2D (PCA)
best_k = max(cluster_results, key=lambda k: silhouette_values[k_values.index(k)])  # k con mejor silhouette
best_labels = cluster_results[best_k]

plt.figure(figsize=(7, 5))
plt.scatter(df_pca[:, 0], df_pca[:, 1], c=best_labels, cmap='rainbow', alpha=0.7)
plt.title(f'Visualización de Clusters con PCA (k={best_k})')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.26" 2025-01-21; OpenJDK Runtime Environment (build 11.0.26+4-post-Ubuntu-1ubuntu122.04); OpenJDK 64-Bit Server VM (build 11.0.26+4-post-Ubuntu-1ubuntu122.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.11/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpa9o29zua
#   JVM stdout: /tmp/tmpa9o29zua/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpa9o29zua/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# ...
# Please download and install the latest version from: https://h2o-release.s3.amazonaws.com/h2o/latest_stable.html
# --------------------------  -----------------------------------------------------------------------------------------
# ...

# %%
sse_values
# Out:
# [8842.901299303756,
#  1128.4501859244829,
#  366.63055115795174,
#  25.076502463169103,
#  12.094382399036931,
#  3.8062496294427335e-11,
#  3.806249809410023e-11,
#  3.806250805548273e-11]

# %%
silhouette_values
# Out:
# [0.8384058333510502,
#  0.953974659626845,
#  0.9851457021327372,
#  0.9958736449523575,
#  0.9973024403817744,
#  1.0,
#  1.0,
#  1.0]

# %%
pd.DataFrame(best_labels).value_counts()
# Out:
# 0
# 2    3758
# 0    3536
# 1    2198
# 5     254
# 3     221
# 4      10
# 6       9
# Name: count, dtype: int64

# %%
df_concatenado_final[best_labels==0]#.index
# Out:
#        periodo   folio  entidad  control  viv_sel  num_hog  hog_mud  p1  p2  \
# 1983       220  12A192        1    40091        4        1        0   1   1
# 1984       220  12A192        1    40091        1        1        0   1   1
# 1986       220  11B176        1    40131        3        1        0   1   1
# 1987       220  11B176        1    40131        4        1        0   1   1
# 1989       220  12B176        1    40132        1        1        0   1   1
# ...        ...     ...      ...      ...      ...      ...      ...  ..  ..
# 11959      224  12A228       32    40220        4        1        0   1   1
# 11961      224  12B215       32    40360        4        1        0   1   1
# 11962      224  12B215       32    40360        2        1        0   1   1
# 11963      224  12B215       32    40360        1        1        0   1   1
# 11964      224  12B222       32    40420        3        1        0   1   1
#
# ...

# %%
# prompt: necesito que me ordenes las características con mayor relevancia luego de realizar lo siguiente:
# pca = PCA(n_components=2)
# df_pca = pca.fit_transform(df_transformed)

import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming 'df_concatenado_final' is your DataFrame
# and it has been preprocessed as shown in the code.

# Select numerical columns for PCA
numeric_cols = df_concatenado_final.select_dtypes(include=['number'])

# Scale the data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(numeric_cols)

# Apply PCA
pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_scaled)

# Get explained variance ratios
explained_variance_ratio = pca.explained_variance_ratio_

# Create a DataFrame with feature importance based on explained variance
feature_importance = pd.DataFrame({'feature': numeric_cols.columns,
                                    'importance': abs(pca.components_[0])}) # Use absolute value for ranking

# Sort by importance in descending order
feature_importance = feature_importance.sort_values('importance', ascending=False)


print("Feature Importance after PCA:")
print(feature_importance)

#Now you have feature_importance sorted, so you can access the features in order of importance:
most_important_features = feature_importance["feature"].to_list()
print("\nMost important features (ordered):", most_important_features)
# Out:
# Feature Importance after PCA:
#      feature    importance
# 36     p12_9  1.688438e-01
# 91  perslecl  1.685673e-01
# 32     p12_5  1.671413e-01
# 28     p12_1  1.658048e-01
# 30     p12_3  1.646021e-01
# ..       ...           ...
# 2    control  3.348976e-03
# 3    viv_sel  6.203127e-04
# 6         p1  5.360750e-04
# 5    hog_mud  3.559405e-04
# 4    num_hog  6.938894e-18
#
# [92 rows x 2 columns]
#
# ...

# %%
most_important_features[:10]
# Out:
# ['p12_9',
#  'perslecl',
#  'p12_5',
#  'p12_1',
#  'p12_3',
#  'p12_8',
#  'r_format',
#  'p14_1',
#  'p12_4',
#  'p12_7']

# %% [markdown]
# ### comparación de poblaciones

# %%
pd.DataFrame(best_labels).value_counts()
# Out:
# 0
# 2    3758
# 0    3536
# 1    2198
# 5     254
# 3     221
# 4      10
# 6       9
# Name: count, dtype: int64

# %%
df_concatenado_final[best_labels==0]
df_concatenado_final[best_labels==1]
df_concatenado_final[best_labels==3]
# Out:
#        periodo   folio  entidad  control  viv_sel  num_hog  hog_mud  p1  p2  \
# 2104       220  13B176        4    40115        3        1        0   2   0
# 2133       220  12A192        5    40031        3        1        0   2   0
# 2174       220  11B188        5    40282        1        1        0   2   0
# 2187       220  11A192        6    40125        4        1        0   2   0
# 2208       220  11B188        6    40280        3        1        0   2   0
# ...        ...     ...      ...      ...      ...      ...      ...  ..  ..
# 11794      224  11A228       28    40278        2        1        0   2   0
# 11870      224  11A228       30    41189        3        1        0   2   0
# 11883      224  11B222       30    41318        2        1        0   2   0
# 11920      224  12A228       31    40224        2        1        0   2   0
# 11923      224  11B222       31    40228        1        1        0   2   0
#
# ...

# %%
# @title Segmentación de base de datos
# Selección de registros con bpm
# @markdown Análisis exploratorio de datos (EDA)
#Configurar las opciones de visualizacion Sweetviz
sw.config_parser.read_string("""
                              [Output_Defaults]
                              html_layout = widescreen
                              html_scale = 1.0
                              notebook_layout = widescreen
                              notebook_scale = 0.9
                              notebook_width = 100%
                              notebook_height = 700
                              [Layout]
                              show_logo = 0
                              """)
base1 = 'registros_grupo_1'
base2 = 'registros_grupo_2'
columnas = df_concatenado_final.columns
for col in columnas:
  # try:
    # df_concatenado_final[col] = pd.to_numeric(df_concatenado_final[col])
  # except:
    df_concatenado_final[col] = df_concatenado_final[col].astype(str)

advert_report = sw.compare([df_concatenado_final[best_labels==0], base1], [df_concatenado_final[best_labels==1], base2]) # Realizamos el análisis de la base de datos inicial

#@markdown Guardar y mostrar reporte formato HTML
advert_report.show_html('EDA_df_concatenado__comparativa_cluster.html')

#@markdown Descarga y abre el reporte en una nueva pestaña del navegador
almacenar_archivo = input('Alamcenar archivo Si o No: ').title()
if almacenar_archivo == 'Si':
  files.download('/content/EDA_df_concatenado__comparativa_cluster.html')
# Out:
# <ipython-input-83-9b853493bd7e>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concatenado_final[col] = df_concatenado_final[col].astype(str)
# <ipython-input-83-9b853493bd7e>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concatenado_final[col] = df_concatenado_final[col].astype(str)
# <ipython-input-83-9b853493bd7e>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#@title La función advert_report.show_notebook en Sweetviz muestra el reporte de análisis exploratorio de datos (EDA) en un notebook Jupyter.

# Parámetros:

# layout: ajusta el diseño ( 'widescreen' o 'full screen' )
# w y h: ajusta el ancho y alto en píxeles
# scale: ajusta el tamaño (0.9 = 90% de la resolución original)
advert_report.show_notebook(layout='widescreen', w=1500, h=500, scale=0.9)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# @title Segmentación de base de datos
# Selección de registros con bpm
# @markdown Análisis exploratorio de datos (EDA)
#Configurar las opciones de visualizacion Sweetviz
sw.config_parser.read_string("""
                              [Output_Defaults]
                              html_layout = widescreen
                              html_scale = 1.0
                              notebook_layout = widescreen
                              notebook_scale = 0.9
                              notebook_width = 100%
                              notebook_height = 700
                              [Layout]
                              show_logo = 0
                              """)
base1 = 'registros_grupo_2'
base2 = 'registros_grupo_3'
columnas = df_concatenado_final.columns
for col in columnas:
  # try:
    # df_concatenado_final[col] = pd.to_numeric(df_concatenado_final[col])
  # except:
    df_concatenado_final[col] = df_concatenado_final[col].astype(str)

advert_report = sw.compare([df_concatenado_final[best_labels==1], base1], [df_concatenado_final[best_labels==3], base2]) # Realizamos el análisis de la base de datos inicial

#@markdown Guardar y mostrar reporte formato HTML
advert_report.show_html('EDA_df_concatenado__comparativa_cluster2.html')

#@markdown Descarga y abre el reporte en una nueva pestaña del navegador
almacenar_archivo = input('Alamcenar archivo Si o No: ').title()
if almacenar_archivo == 'Si':
  files.download('/content/EDA_df_concatenado__comparativa_cluster2.html')
# Out:
# <ipython-input-85-50e4207380cf>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concatenado_final[col] = df_concatenado_final[col].astype(str)
# <ipython-input-85-50e4207380cf>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concatenado_final[col] = df_concatenado_final[col].astype(str)
# <ipython-input-85-50e4207380cf>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#@title La función advert_report.show_notebook en Sweetviz muestra el reporte de análisis exploratorio de datos (EDA) en un notebook Jupyter.

# Parámetros:

# layout: ajusta el diseño ( 'widescreen' o 'full screen' )
# w y h: ajusta el ancho y alto en píxeles
# scale: ajusta el tamaño (0.9 = 90% de la resolución original)
advert_report.show_notebook(layout='widescreen', w=1500, h=500, scale=0.9)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # El aprendizaje es un regalo y la IA nos lo obsequia.
#
# # ¡GRACIAS!
#
# ![](https://img.freepik.com/foto-gratis/celebracion-futurista-vispera-ano-nuevo_23-2151084717.jpg?t=st=1742005732~exp=1742009332~hmac=27ebf8737e92b52e0e44cbd53b26ae68064d4193bbce91789123f39a873e62a4&w=900)
