# %% [markdown]
# # Autenticador del Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Suponiendo que ya tienes los datos
# y_pred es el conjunto de predicciones del modelo
# y_test es el conjunto real de etiquetas

# Generar la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

# Normalizar por filas para ver proporciones
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Visualizar con un heatmap
plt.figure(figsize=(8,6))
sns.heatmap(cm_norm, annot=True, fmt=".2f", cmap="Blues", xticklabels=[1,2,3,4,5,9], yticklabels=[1,2,3,4,5,9])
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.title("Matriz de Confusión Normalizada")
plt.show()
plt.figure(figsize=(8,5))
sns.histplot(y_pred, bins=np.arange(1, 11)-0.5, kde=False)
plt.xticks([1,2,3,4,5,9])
plt.xlabel("Clases Predichas")
plt.ylabel("Frecuencia")
plt.title("Distribución de Predicciones")
plt.show()

# %% [markdown]
# # Librerias

# %%
# !pip install pandas-profiling
# !pip install pyxlsb
# !pip install sweetviz
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.6/262.6 kB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 65.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.8/309.8 kB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 21.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 70.6 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=581b57bb65ba81a03e54afed93a17e5e0aa8758e134c49767d4bfb76784a3e22
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
# ...

# %%
import os
import re
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
import sweetviz as sv
from google.colab import files
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f2140f9e1a8f> in <cell line: 0>()
#       7 import matplotlib.patches as mpatches
#       8 import matplotlib.pyplot as plt
# ----> 9 from ydata_profiling import ProfileReport
#      10 import sweetviz as sv
#      11 from google.colab import files
#
# ModuleNotFoundError: No module named 'ydata_profiling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Funciones

# %%
def missing_values(data):
  df = pd.DataFrame()
  for col in list(data):
    unique_values = data[col].unique()
    try:
      unique_values = np.sort(unique_values)
    except:
      pass
    nans = round(pd.isna(data[col]).sum()/data.shape[0]*100, 1)
    # zeros = round((data[col] == 0).sum()/data.shape[0]*100, 1)
    df = pd.concat([df, pd.DataFrame([[col, len(unique_values), nans]], columns=['variable', 'unique value', 'NaN %'])], ignore_index=True)
  return df.rename(columns={'NaN %':'Nan %', 'Zeros %': 'Zeros %'}).sort_values('Nan %', ascending=False)

# %% [markdown]
# # Ruta de los datos

# %%
path = '/content/drive/MyDrive/CURSO_GESTION_DATOS_CLINICOS/Modulo3_Modelos/'
path2 = '/content/drive/MyDrive/CURSO_GESTION_DATOS_CLINICOS/Modulo3_Modelos/Datasets/Mental Health Dataset.csv'

# %% [markdown]
# # Cargar bases de datos

# %%
df1 = pd.read_csv(path+'heart_disease_data.csv')

df3 = pd.read_csv(path2)

df3.head(3)

# %%
df3.columns

# %% [markdown]
# # EDA

# %%
missing_v = missing_values(df1)
missing_v

# %% [markdown]
# # EDA INICIAL

# %%
#Configurar las opciones de visualizacion Sweetviz
sv.config_parser.read_string("""
[Output_Defaults]
html_layout = widescreen
html_scale = 1.0
notebook_layout = widescreen
notebook_scale = 0.9
notebook_width = 100%%
notebook_height = 700
[Layout]
show_logo = 0
""")

df2 = df1.copy()

#df2['fecha'] = df2['fecha'].astype('str')

#crear la configuracion de caracteristicas

#feature_confing = sv.FeatureConfig(skip=['ID'], force_text=['fecha'], force_cat=['Genero'])




advert_report = sv.analyze(df2) #,feature_confing

#Guardar y mostrar reporte formato HTML
advert_report.show_html('EDA_df1.html')

#Descarga y abre el reporte en una nueva pestaña del navegador
files.download('/content/EDA_df1.html')
